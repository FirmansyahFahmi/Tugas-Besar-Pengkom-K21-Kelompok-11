# %% [markdown]
# Tugas Besar Pengenalan Komputasi
# KU1102 / K21
# Analisis Data Penyebaran Tempat Ibadah di Kota Administrasi Jakarta Utara
# Kelompok 11:
# 1. Dave Jansen Ongkaputra (19622147)
# 2. Emery Fathan Zwageri (19622007)
# 3. Firmansyah Fahmi Nugraha (16522047)
# 4. Tazkia Nizami (19622077)

# %%
import pandas as pd
import os as os
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('Analisis Data.csv')

# %% [markdown]
# Data (Analisis Data.csv) yang kami gunakan adalah data penyebaran tempat ibadah di Kota Administrasi Jakarta Utara yang meliputi masjid, musholla, gereja, vihara dan pura dengan format data adalah .csv. Data ini dibuat pada tahun 27 April 2016 dengan terakhir diperbarui pada 13 Maret 2019 dan berasal dari web resmi dataset Jakarta (https://data.jakarta.go.id/dataset/data-penyebaran-tempat-ibadah-di-jakarta-utara).

# %%
print("Baris       : " + str(data.shape[0]) + " baris")
print("Kolom       : " + str(data.shape[1]) + " kolom")
print("Ukuran file : " + str((os.stat('Analisis Data.csv').st_size)/1000000) + " mb")
# Out:
# Baris       : 1845 baris
# Kolom       : 17 kolom
# Ukuran file : 0.2309 mb

# %% [markdown]
# Berdasarkan informasi baris, kolom, dan ukuran file di atas, data tersebut memiliki dimensi 1845 baris dan 17 kolom serta ukuran file sebesar 0.2309 mb.

# %% [markdown]
# Penjelasan mengenai atribut/kolom pada dataset ini:
#
# 1. kab/kota           : nama kabupaten/kota administrasi (kategorikal, nominal)
# 2. kecamatan          : nama kecamatan (kategorikal, nominal)
# 3. kelurahan          : nama kelurahan (kategorikal, nominal)
# 4. tempat_ibadah      : nama tempat ibadah (kategorikal, nominal)
# 5. alamat             : lokasi tempat ibadah (kategorikal, nominal)
# 6. nama_pengurus      : nama pengurus tempat ibadah (kategorikal, nominal)
# 7. status_tanah       : asal status tanah tempat ibadah (kategorikal, nominal)
# 8. tahun_pendirian    : tahun pendirian tempat ibadah (kuantitatif, diskrit)
# 9. bentuk_bangunan    : bentuk bangunan (kategorikal, nominal)
# 10. sumber_biaya      : asal biaya (kategorikal, nominal)
# 11. peruntukkan_lahan : peruntukkan lahan (kategorikal, nominal)
# 12. kepemilikkan      : kepemilikan tempat ibadah (kategorikal, nominal)
# 13. daya_tampung      : daya tampung jamaah (kuantitatif, diskrit)
# 14. luas_bangunan     : luas bangunan tempat ibadah (dalam meter persegi) (kuantitatif, kontinu)
# 15. luas_tanah        : luas tanah (dalam meter persegi) (kuantitatif, kontinu)
# 16. kegiatan_lain     : kegiatan lain (kategorikal, nominal)
#
# Informasi tambahan terkait kegiatan lain:
# TPA : Taman Pendidikan Al-Qurán;
# RM  : Remaja Masjid;
# MT  : Majlis Ta'lim; dan
# Mad : Madrasah

# %%
print("Data Kotor/Kosong dalam Persen:")
persen = data.isnull().mean() * 100
print(round(persen,2))
# Out:
# Data Kotor/Kosong dalam Persen:
# kab/kota              0.00
# kecamatan             0.00
# kelurahan             1.19
# tempat_ibadah         0.00
# alamat                0.00
# nama_pengurus        10.03
# status_tanah         31.27
# tahun_pendirian      34.80
# bentuk_bangunan      30.73
# sumber_biaya         79.46
# peruntukkan_lahan    86.02
# kepemilikkan         88.35
# pemberi_Wakaf        95.28
# daya_tampung         78.92
# luas_bangunan        28.51
# luas_tanah           25.47
# kegiatan_lain        92.14
# dtype: float64

# %% [markdown]
# Berdasarkan informasi persen data yang kosong di atas, data untuk atribut 'kab/kota', 'kecamatan', 'tempat_ibadah', dan 'alamat' tidak terdapat data yang kosong, namun untuk atribut lainnya terdapat data yang kosong dengan persentase pada informasi di atas.

# %%
print(data['kab/kota'].unique())
# Out:
# ['Jakarta Utara']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'kab/kota' berisi cakupan wilayah data, yaitu 'Jakarta Utara'.

# %%
print(data['kecamatan'].unique())
# Out:
# ['Cilincing' 'Kelapa Gading' 'Koja' 'Pademangan' 'Penjaringan'
#  'Tanjung Priok']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'kecamatan' berisi kecamatan di wilayah Jakarta Utara, yaitu 'Cilincing', 'Kelapa Gading', 'Koja', 'Pademangan', 'Penjaringan', dan 'Tanjung Priok'.

# %%
print(data['kelurahan'].unique())
# Out:
# ['Cilincing' 'Kali Baru' 'Marunda' 'Rorotan' 'Semper Barat' 'Semper Timur'
#  'Sukapura' 'Kelapa Gading Barat' 'Kelapa Gading Timur' 'Pegangsaan Dua'
#  nan 'Koja' 'Lagoa' 'Rawa Badak Selatan' 'Rawa Badak Utara' 'Tugu Selatan'
#  'Tugu Utara' 'Ancol' 'Pademangan Barat' 'Pademangan Timur' 'Kamal Muara'
#  'Penjagalan' 'Penjaringan' 'Pluit' 'Kebon Bawang' 'Papango'
#  'Sungai Bambu' 'Sunter Agung' 'Sunter Jaya' 'Tanjung Priok' 'Warakas']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'kelurahan' berisi kelurahan di wilayah Jakarta Utara, yaitu 'Ancol', 'Cilincing', 'Kali Baru', 'Kamal Muara', 'Kebon Bawang', 'Kelapa Gading Barat', data kosong, dst.

# %%
print(data['tempat_ibadah'].unique())
# Out:
# ['Musholla Babus Salam' 'Musholla Jamiatul Ikhlas'
#  'Musholla Nur Baitur Rahmah' ... "Baitul Ma'ruf" 'Baitul Haq'
#  'Nurul Amal']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'tempat_ibadah' berisi jenis serta nama tempat ibadah, yaitu 'Masjid Nurhidayah', 'Masjid Al Barokah', 'Masjid Darul Ilmi', dst.

# %%
print(data['alamat'].unique())
# Out:
# ['Jl. Cilingcing Rt. 001/06' 'Jl. Baru Gg IV Dalam No.20 Rt.006/02'
#  'Jl. Gg.Usaha No.9 Rt. 010/04' ... 'Jl. Warakas Gg. 12 Rt. 014/10'
#  'Jl. Warakas Rt. 003/12' 'Jl. Warakas ']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'alamat' berisi alamat dari tempat ibadah, yaitu 'Jl. Kebon Tebu Rt. 016/17', 'Jl. Muara Baru Kebon Tebu Blok C Rt. 016/17', 'Jl. Muara Baru Rt. 022/17', dst.

# %%
print(data['nama_pengurus'].unique())
# Out:
# ['Icang' 'Halimah' 'Tojib' ... 'Memen' 'Tata Sumanta' 'Anang']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'nama_pengurus' berisi nama pengurus dari tempat ibadah, yaitu 'Serajudin Gunawan', 'Hudallah M', 'Medi', data kosong, dst.

# %%
print(data['status_tanah'].unique())
# Out:
# ['Negara' nan 'Hak Milik' 'Wakaf' 'Tanah Pasum' 'Milik STIP' 'Adat' 'SHM'
#  'Sertifikat' 'Hak Guna Bangunan' 'Milik' 'Pemda' 'Warga' 'Hak Pakai'
#  'TNI AL' 'Fasos' 'Yayasan' 'Garap' 'Pemerintah']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'status_tanah' berisi status tanah tempat ibadah, yaitu 'Hak Guna Bangunan', 'Hak Pakai', 'Negara', data kosong, dst.

# %%
sort = data.sort_values('tahun_pendirian')

print(sort['tahun_pendirian'].unique())
# Out:
# [1650. 1891. 1918. 1920. 1930. 1931. 1932. 1938. 1940. 1945. 1946. 1947.
#  1948. 1949. 1950. 1951. 1953. 1954. 1955. 1956. 1957. 1958. 1959. 1960.
#  1961. 1962. 1963. 1964. 1965. 1966. 1967. 1968. 1969. 1970. 1971. 1972.
#  1973. 1974. 1975. 1976. 1977. 1978. 1979. 1980. 1981. 1982. 1983. 1984.
#  1985. 1986. 1987. 1988. 1989. 1990. 1991. 1992. 1993. 1994. 1995. 1996.
#  1997. 1998. 1999. 2000. 2001. 2002. 2003. 2004. 2005. 2006. 2007.   nan]

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'tahun_pendirian' berisi tahun pendirian tempat ibadah dengan range tahun pendirian mulai tahun 1650 - 2007.

# %%
print(data['bentuk_bangunan'].unique())
# Out:
# ['Permanen' nan 'Semi Permanen' 'Darurat']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'bentuk_bangunan' berisi bentuk bangunan tempat ibadah, yaitu 'Permanen', 'Semi Permanen', 'Darurat', dan data kosong.

# %%
print(data['sumber_biaya'].unique())
# Out:
# [nan 'Swadaya Masa' 'Masyarakat' 'Perorangan' 'Lem. Sosial' 'Pemerintah'
#  'Pt. Nusa Kirana' 'Lainnya' 'Wakaf, Perorangan']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'sumber_biaya' berisi sumber biaya pembangunan tempat ibadah, yaitu 'Swadaya Masa', 'Perorangan', 'Masyarakat', data kosong, dst.

# %%
print(data['peruntukkan_lahan'].unique())
# Out:
# [nan 'SSI' 'Lainnya']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'peruntukan_lahan' berisi peruntukan lahan tempat ibadah, yaitu 'SSI', 'Lainnya', dan data kosong.

# %%
print(data['kepemilikkan'].unique())
# Out:
# [nan 'Masyarakat' 'Wakaf' 'Pribadi' 'TNI AL' 'Pemda DKI' 'Yayasan'
#  'Swadaya Masa' 'Pribadi & Wakaf' 'Pemerintah']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'kepemilikan' berisi kepemilikan tempat ibadah, yaitu 'Masyarakat', 'Wakaf', 'Pemerintah', 'Pribadi', data kosong, dst

# %%
sort = data.sort_values('daya_tampung')

print(sort['daya_tampung'].unique())
# Out:
# [  20.   30.   35.   40.   45.   49.   50.   60.   66.   70.   75.   80.
#    85.   88.   90.  100.  120.  125.  130.  137.  140.  150.  172.  180.
#   200.  210.  220.  230.  240.  250.  260.  280.  300.  315.  350.  400.
#   450.  500.  525.  600.  700.  750.  800. 1000. 1200. 1500. 1800. 2500.
#    nan]

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'daya_tampung' berisi daya tampung tempat ibadah dengan range daya tampung tempat ibadah mulai 20 - 2500 orang, serta data kosong.

# %%
sort = data.sort_values('luas_bangunan')
sort['luas_bangunan'] = sort['luas_bangunan'].astype(str).replace('\.0', '', regex=True)

print(sort['luas_bangunan'].unique())
# Out:
# ['3' '8' '10' '16' '18' '19' '20' '21' '24' '25' '28' '30' '31' '32' '33'
#  '35' '36' '37' '38' '39' '40' '42' '45' '46' '47' '48' '49' '50' '52'
#  '53' '54' '55' '56' '58' '60' '63' '64' '65' '66' '67' '68' '69' '70'
#  '72' '73' '74' '75' '76' '77' '78' '80' '81' '84' '85' '86' '87' '88'
#  '90' '91' '92' '93' '94' '95' '96' '98' '99' '100' '102' '103' '104'
#  '105' '108' '110' '111' '112' '115' '117' '118' '120' '121' '125' '128'
#  '130' '132' '134' '135' '139' '140' '143' '144' '145' '149' '150' '153'
#  '154' '155' '156' '160' '163' '168' '169' '170' '171' '175' '176' '180'
#  '182' '184' '187' '188' '190' '192' '195' '196' '198' '200' '204' '206'
#  '210' '212' '216' '220' '224' '225' '230' '233' '235' '236' '240' '244'
#  '250' '252' '253' '254' '256' '260' '263' '264' '268' '270' '272' '275'
#  '280' '281' '286' '288' '289' '300' '303' '305' '310' '320' '322' '324'
#  '336' '342' '350' '352' '354' '360' '370' '372' '375' '378' '380' '387'
# ...

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'luas_bangunan' berisi luas bangunan tempat ibadah dengan range luas bangunan tempat ibadah mulai dari 3 - 5400 meter persegi, dan data kosong. Namun, luas tanah 3 meter persegi tidak mungkin, maka terdapat data "out of range" pada atribut ini.

# %%
sort = data.sort_values('luas_tanah')
sort['luas_tanah'] = sort['luas_tanah'].astype(str).replace('\.0', '', regex=True)
print(sort['luas_tanah'].unique())
# Out:
# ['0' '6' '7' '12' '16' '17' '18' '19' '20' '21' '23' '24' '25' '27' '28'
#  '30' '31' '32' '33' '35' '36' '38' '39' '40' '42' '44' '45' '46' '47'
#  '48' '49' '50' '52' '53' '54' '55' '56' '58' '60' '61' '63' '64' '65'
#  '66' '68' '70' '72' '73' '74' '75' '76' '77' '78' '80' '81' '84' '85'
#  '86' '87' '88' '90' '91' '93' '94' '95' '96' '98' '99' '100' '102' '104'
#  '105' '108' '110' '111' '112' '115' '117' '118' '120' '121' '122' '125'
#  '126' '127' '128' '130' '132' '134' '135' '140' '143' '144' '145' '150'
#  '153' '154' '155' '158' '159' '160' '161' '162' '163' '165' '168' '170'
#  '171' '175' '176' '180' '182' '183' '184' '185' '186' '187' '188' '190'
#  '191' '195' '196' '198' '200' '203' '207' '208' '210' '212' '218' '220'
#  '224' '225' '228' '229' '230' '235' '236' '240' '242' '244' '250' '253'
#  '256' '260' '263' '266' '268' '270' '272' '275' '276' '280' '281' '283'
#  '284' '286' '290' '295' '298' '300' '305' '306' '310' '320' '322' '325'
# ...

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'luas_tanah' berisi luas tanah tempat ibadah dengan range luas tanah tempat ibadah mulai dari 0 - 9850 meter persegi, dan data kosong. Namun, luas tanah 0 meter persegi tidak mungkin, maka terdapat data "out of range" pada atribut ini.

# %%
print(data['kegiatan_lain'].unique())
# Out:
# [nan 'MT, RM' 'MT' 'TPA, MT' 'Lainnya' 'TPA, MT, Mad'
#  'TPA, MT, RM, Lainnya' 'TPA, Lainnya' 'MT, Lainnya' 'TPA, RM'
#  'TPA, MT, RM' 'TPA, MT, Mad, RM' 'TPA, MT, RM ' 'MT, RM, Lainnya' 'TPA'
#  'RM' 'MT, Mad, RM' 'Mad' 'TPA, MT, Mad , RM' 'Mad, RM']

# %% [markdown]
# Berdasarkan informasi di atas, data untuk atribut 'kegiatan_lain' berisi kegiatan lain yang dilakukan di tempat ibadah, yaitu 'MT, RM', 'MT', 'Lainnya', 'TPA, MT, RM', 'TPA, MT', 'TPA', data kosong, dst.

# %%
data1 = data.astype(str).replace('\.0', '', regex=True)
data1.astype(str).replace('\.0', '', regex=True)
data1[1141:1144]
# Out:
#            kab/kota   kecamatan         kelurahan           tempat_ibadah  \
# 1141  Jakarta Utara  Pademangan  Pademangan Timur  Masjid Nurul Mujahidin
# 1142  Jakarta Utara  Pademangan  Pademangan Timur   Masjid Jami Al Ikhsan
# 1143  Jakarta Utara  Pademangan  Pademangan Timur       Masjid Al Barokah
#
#                          alamat nama_pengurus status_tanah tahun_pendirian  \
# 1141  Jl. Pad. VIII Rt. 006/ 10       A. Ukro        Wakaf            1999
# 1142     Pad  II Gg 13 Rt010/05     R. Asmaun    Hak Milik            1998
# 1143      Jl. Pad IV Rt. 001/08   Saleh Djaya        Wakaf            1950
#
#      bentuk_bangunan  sumber_biaya peruntukkan_lahan kepemilikkan  \
# 1141        Permanen  Swadaya Masa               SSI   Masyarakat
# 1142        Permanen  Swadaya Masa               SSI   Masyarakat
# 1143        Permanen  Swadaya Masa               SSI   Masyarakat
#
#      pemberi_Wakaf daya_tampung luas_bangunan luas_tanah    kegiatan_lain
# ...

# %% [markdown]
# Data di atas adalah 3 data pada baris ke 1141 - 1143. Alasan engambil data pada range ini dikarenakan hanya ada 1 data yang kosong, sehingga memudahkan dalam menjelaskan sampel data.
#
# Untuk data pada baris 1141:
# Di Kota Jakarta Utara, Kecamatan Pademangan, Kelurahan Pademangan Timur, terdapat tempat ibadah yang sudah berdiri permanen sejak tahun 1999 dengan jenis tempat ibadah adalah Masjid dengan nama "Masjid Nurul Mujahidin" yang beralamat di Jalan Pad. VIII RT 006 / RW 10 yang diurus oleh Bapak A. Ukro. Masjid ini adalah masjid milik masyarakat dan merupakan hasil wakaf masyarakat dengan sumber biaya dari swadaya masa yang diperuntukkan untuk SSI. Masjid yang memiliki daya tampung 120 orang dengan luas bangunan 100 meter persegi yang berdiri kokoh diatas tanah 100 meter persegi memiliki kegiatan lain selain dari fungsinya sebagai tempat ibadah, yaitu Majlis Ta'lim (MT) dan Remaja Masjid (RM).
#
# Untuk data pada baris 1142:
# Di Kota Jakarta Utara, Kecamatan Pademangan, Kelurahan Pademangan Timur, terdapat tempat ibadah yang sudah berdiri permanen sejak tahun 1998 dengan jenis tempat ibadah adalah Masjid dengan nama "Masjid Jami Al Ikhsan" yang beralamat di Jalan Pad II Gg 13 RT 010 / RW 05 yang diurus oleh Bapak R. Asmaun. Masjid ini adalah masjid milik masyarakat dan merupakan hak milik masyarakat dengan sumber biaya dari swadaya masa yang diperuntukkan untuk SSI. Masjid yang memiliki daya tampung 300 orang dengan luas bangunan 100 meter persegi yang berdiri kokoh diatas tanah 100 meter persegi memiliki kegiatan lain selain dari fungsinya sebagai tempat ibadah, yaitu Majlis Ta'lim (MT).
#
# Untuk data pada baris 1143:
# Di Kota Jakarta Utara, Kecamatan Pademangan, Kelurahan Pademangan Timur, terdapat tempat ibadah yang sudah berdiri permanen sejak tahun 1950 dengan jenis tempat ibadah adalah Masjid dengan nama "Masjid Al Barokah" yang beralamat di Jalan Pad IV RT 001 / RW 08 yang diurus oleh Bapak Saleh Djaya. Masjid ini adalah masjid milik masyarakat dan merupakan hasil wakaf dari Bapak Keri dengan sumber biaya dari swadaya masa yang diperuntukkan untuk SSI. Masjid yang memiliki daya tampung 150 orang dengan luas bangunan 121 meter persegi yang berdiri kokoh diatas tanah 121 meter persegi memiliki kegiatan lain selain dari fungsinya sebagai tempat ibadah, yaitu Majlis Ta'lim (MT), Remaja Masjid (RM), dan lainnya.

# %%
list_ratarata = []
list_ratarata.append(["Atribut", "Rata-Rata"])
a = data['tahun_pendirian'].mean(skipna = True)
list_ratarata.append(["Tahun Pendirian", round(a)])
b = data['daya_tampung'] .mean(skipna = True)
list_ratarata.append(["Daya Tampung", round(b)])
c = data['luas_bangunan'].mean(skipna = True)
list_ratarata.append(["Luas Bangunan", round(c)])
d = data['luas_tanah'].mean(skipna = True)
list_ratarata.append(["Luas Tanah", round(d)])


fig, ax = plt.subplots()
table = ax.table(cellText=list_ratarata, loc='center')
table.set_fontsize(10)
table.scale(1, 2)
ax.axis('off')
plt.title("Rata-Rata Atribut")
plt.show()

# %% [markdown]
# Berdasarkan informasi rata-rata atribut di atas, kita dapat melihat bahwa:
#
# Tahun Pendirian:
# Rata-rata : 1978
#
# Daya Tampung:
# Rata-rata : 277
#
# Luas Bangunan:
# Rata-rata : 177
#
# Luas Tanah:
# Rata-rata : 274

# %%
list_std = []
list_std.append(["Atribut", "Standar Deviasi"])
a = data['tahun_pendirian'].std()
list_std.append(["Tahun Pendirian", a])
b = data['daya_tampung'].std()
list_std.append(["Daya Tampung", b])
c = data['luas_bangunan'].std()
list_std.append(["Luas Bangunan", c])
d = data['luas_tanah'].std()
list_std.append(["Luas Tanah", d])


fig, ax = plt.subplots()
table = ax.table(cellText=list_std, loc='center')
table.set_fontsize(10)
table.scale(1, 2)
ax.axis('off')
plt.title("Standar Deviasi Atribut")
plt.show()

# %% [markdown]
# Berdasarkan informasi standar deviasi atribut di atas, kita dapat melihat bahwa:
#
# Tahun Pendirian:
# Standar deviasi : 15,420
#
# Daya Tampung:
# Standar deviasi : 288,776
#
# Luas Bangunan:
# Standar deviasi : 277,076
#
# Luas Tanah:
# Standar deviasi : 601,375

# %%
list_maxmin = []
list_maxmin.append(["Atribut", "Max", "Min"])
a1 = data['tahun_pendirian'].max()
a2 = data['tahun_pendirian'].min()
list_maxmin.append(["Tahun Pendirian", round(a1), round(a2)])
b1 = data['daya_tampung'].max()
b2 = data['daya_tampung'].min()
list_maxmin.append(["Daya Tampung", round(b1), round(b2)])
c1 = data['luas_bangunan'].max()
c2 = data['luas_bangunan'].min()
list_maxmin.append(["Luas Bangunan", round(c1), round(c2)])
d1 = data['luas_tanah'].max()
d2 = data['luas_tanah'].min()
list_maxmin.append(["Luas Tanah", round(d1), round(d2)])


fig, ax = plt.subplots()
table = ax.table(cellText=list_maxmin, loc='center')
table.set_fontsize(10)
table.scale(1, 2)
ax.axis('off')
plt.title("Nilai Maksimum Minimum Atribut")
plt.show()

# %% [markdown]
# Berdasarkan informasi nilai maksimum dan minimum atribut di atas, kita dapat melihat bahwa:
#
# Tahun Pendirian:
# Nilai maksimum : 2007
# Nilai minimum  : 1650
#
# Daya Tampung:
# Nilai maksimum : 2500
# Nilai minimum  : 20
#
# Luas Bangunan:
# Nilai maksimum : 5400
# Nilai minimum  : 3 (data out of range)
#
# Luas Tanah:
# Nilai maksimum : 9850
# Nilai minimum  : 0 (data out of range)

# %%
list_percentile = []
list_percentile.append(["Persen", "Tahun Pendirian", "Daya Tampung", "Luas Bangunan", "Luas Tanah"])

for num in range(10, 110, 10):
    percent = round(num * 0.01, 1)
    start_percent = round(percent - 0.1, 1)
    end_percent = percent
    str_percentage = f"{(int(start_percent * 100))}% - {int(end_percent * 100)}%"
    str_nominal1 = f"{int((data.quantile(end_percent)['tahun_pendirian']))}"
    str_nominal2 = f"{int((data.quantile(end_percent)['daya_tampung']))}"
    str_nominal3 = f"{int((data.quantile(end_percent)['luas_bangunan']))}"
    str_nominal4 = f"{int((data.quantile(end_percent)['luas_tanah']))}"
    list_percentile.append([str_percentage,str_nominal1,str_nominal2,str_nominal3,str_nominal4])

fig, ax = plt.subplots()
table = ax.table(cellText=list_percentile, loc='center')
table.set_fontsize(10)
table.scale(1,2)
ax.axis('off')
plt.title("Persentile Tahun Pendirian, Daya Tampung, Luas Bangunan, dan Luas Tanah")
plt.show()

# %% [markdown]
# Dari statistik persentile tahun pendirian, daya tampung, luas bangunan, dan luas tanah didapati bahwa:
#
# Tahun Pendirian:
# persentile 40% data belum mencapai setengah dari range tahun pendirian yaitu tahun 1978. Dengan demikian, dapat diamsusikan bahwa data

# %%
a = data['kecamatan'].unique()
list_kecamatan = []
list_kecamatan.append(["Kecamatan", "Tempat Ibadah"])

for i in a:
    n = data['kecamatan'].value_counts()[i]
    list_kecamatan.append([i, n])

fig, ax = plt.subplots()
table = ax.table(cellText=list_kecamatan, loc='center')
table.set_fontsize(10)
table.scale(1,2)
ax.axis('off')
plt.title("Distribusi Tempat Ibadah berdasarkan Kecamatan")
plt.show()

# %%
simpan = {}
count = data['kecamatan'].unique()

for i in count:
    simpan[i] = data['kecamatan'].value_counts()[i]

simpan = sorted(simpan.items(), key = lambda x:x[1])
simpan = dict(simpan)
n_tempat_ibadah = pd.DataFrame(simpan, index=[1])
n_tempat_ibadah.plot(kind="bar", title="Distribusi Tempat Ibadah berdasarkan Kecamatan")
# Out:
# <AxesSubplot:title={'center':'Distribusi Tempat Ibadah berdasarkan Kecamatan'}>

# %%
data['kecamatan'].value_counts().plot(kind="pie", explode = [0.05]*6, autopct="%.0f%%", title="Distribusi Tempat Ibadah berdasarkan Kecamatan")
# Out:
# <AxesSubplot:title={'center':'Distribusi Tempat Ibadah berdasarkan Kecamatan'}, ylabel='kecamatan'>

# %% [markdown]
# Berdasarkan data dan grafik distribusi tempat ibadah berdasarkan kecamatan, kita dapat melihat bahwa Kecamatan Cilincing merupakan kecamatan dengan jumlah tempat ibadah paling banyak yaitu sejumlah 471 tempat ibadah dan Kecamatan Kelapa Gading merupakan kecamatan dengan jumlah tempat ibadah paling sedikit yaitu sejumlah 139 tempat ibadah.

# %%
maxim_tahun = data['tahun_pendirian'].max()
minim_tahun = data['tahun_pendirian'].min()
range_tahun = maxim_tahun-minim_tahun
2007, 1975, 1940, 1905, 1870, 1835, 1800, 1765, 1730, 1695, 1650
delta_tahun = [1695, 1870, 1905, 1940, 1975, 2007]
freq = 0
prev_tahun = 1649
list_frek = []
list_frek.append(["Range Tahun", "Tempat Ibadah"])

for i in delta_tahun:
    end_range = i
    start_range = prev_tahun
    query =  (start_range <= data['tahun_pendirian']) & (data['tahun_pendirian'] <= end_range)  

    data1 = data.loc[query].shape[0]
    freq += data1
    str_frek = f"{start_range+1} - {end_range}"
    str_nominal = f"{data1}"
    list_frek.append([str_frek,str_nominal])
    prev_tahun = end_range

fig, ax = plt.subplots()
table = ax.table(cellText=list_frek, loc='center')
table.set_fontsize(12)
table.scale(1,2)
ax.axis('off')
plt.title("Distribusi Tempat Ibadah berdasarkan Tahun")
plt.show()

# %%
D = {u'A':1, u'B':0, u'C':1, u'D':1, u'E':479, u'F':758}

plt.bar(*zip(*D.items()))
plt.title("Distribusi Tempat Ibadah berdasarkan Tahun")
plt.show()

print("""
Keterangan:
A = 1650 - 1695
B = 1696 - 1870
C = 1871 - 1905
D = 1906 - 1940
E = 1941 - 1975
F = 1976 - 2007
""")
# Out:
# Keterangan:
# A = 1650 - 1695
# B = 1696 - 1870
# C = 1871 - 1905
# D = 1906 - 1940
# E = 1941 - 1975
# F = 1976 - 2007

# %%
maxim_tahun = data['tahun_pendirian'].max()
minim_tahun = data['tahun_pendirian'].min()
range_tahun = maxim_tahun-minim_tahun
2007, 1975, 1940, 1905, 1870, 1835, 1800, 1765, 1730, 1695, 1650
delta_tahun = [1695, 1870, 1905, 1940, 1975, 2007]
freq = 0
prev_tahun = 1649
list_frek1 = []
list_frek2 = []

for i in delta_tahun:
    end_range = i
    start_range = prev_tahun
    query =  (start_range <= data['tahun_pendirian']) & (data['tahun_pendirian'] <= end_range)  
    data1 = data.loc[query].shape[0]
    freq += data1
    str_frek = f"{start_range+1} - {end_range}"
    list_frek1.append(str_frek)
    list_frek2.append(data1)
    prev_tahun = end_range

fig , ax = plt.subplots()

ax.pie(list_frek2,labels = list_frek1, explode = [0.05]*6, autopct="%.0f%%")
ax.set_title("Distribusi Tempat Ibadah berdasarkan Tahun", fontsize=16);

# %% [markdown]
# Berdasarkan data dan grafik distribusi tempat ibadah berdasarkan tahun, kita dapat melihat bahwa jumlah tempat ibadah monoton naik yang artinya semakin bertambahnya tahun, maka semakin banyak juga tempat ibadah yang dibangun.

# %% [markdown]
# Hierarki Indexing (ini nanti dijelasin di laporannya)

# %%
data1 = data.copy()
data1 = data1.set_index(['kecamatan', 'kelurahan'], drop=False)
data1
# Out:
#                               kab/kota      kecamatan  kelurahan  \
# kecamatan     kelurahan
# Cilincing     Cilincing  Jakarta Utara      Cilincing  Cilincing
#               Cilincing  Jakarta Utara      Cilincing  Cilincing
#               Cilincing  Jakarta Utara      Cilincing  Cilincing
#               Cilincing  Jakarta Utara      Cilincing  Cilincing
#               Cilincing  Jakarta Utara      Cilincing  Cilincing
# ...                                ...            ...        ...
# Tanjung Priok Warakas    Jakarta Utara  Tanjung Priok    Warakas
#               Warakas    Jakarta Utara  Tanjung Priok    Warakas
#               Warakas    Jakarta Utara  Tanjung Priok    Warakas
#               Warakas    Jakarta Utara  Tanjung Priok    Warakas
#               Warakas    Jakarta Utara  Tanjung Priok    Warakas
#
#                                       tempat_ibadah  \
# kecamatan     kelurahan
# Cilincing     Cilincing        Musholla Babus Salam
# ...

# %%
data1 = data1.swaplevel('kecamatan', 'kelurahan')
data1
# Out:
#                               kab/kota      kecamatan  kelurahan  \
# kelurahan kecamatan
# Cilincing Cilincing      Jakarta Utara      Cilincing  Cilincing
#           Cilincing      Jakarta Utara      Cilincing  Cilincing
#           Cilincing      Jakarta Utara      Cilincing  Cilincing
#           Cilincing      Jakarta Utara      Cilincing  Cilincing
#           Cilincing      Jakarta Utara      Cilincing  Cilincing
# ...                                ...            ...        ...
# Warakas   Tanjung Priok  Jakarta Utara  Tanjung Priok    Warakas
#           Tanjung Priok  Jakarta Utara  Tanjung Priok    Warakas
#           Tanjung Priok  Jakarta Utara  Tanjung Priok    Warakas
#           Tanjung Priok  Jakarta Utara  Tanjung Priok    Warakas
#           Tanjung Priok  Jakarta Utara  Tanjung Priok    Warakas
#
#                                       tempat_ibadah  \
# kelurahan kecamatan
# Cilincing Cilincing            Musholla Babus Salam
# ...

# %%
data1 = data1.groupby(level = 1).sum()
data1
# Out:
#                tahun_pendirian  daya_tampung  luas_bangunan  luas_tanah
# kecamatan
# Cilincing             629936.0       10270.0        58035.0    111857.0
# Kelapa Gading         107169.0       22855.0        24293.0     52532.0
# Koja                  679143.0        6540.0        47471.0     65086.0
# Pademangan            181276.0       27803.0        13229.0     24611.0
# Penjaringan           206301.0       23709.0        21219.0     28279.0
# Tanjung Priok         575704.0       16760.0        68612.0     94885.0

# %%
data.plot(x = 'tahun_pendirian', y = 'daya_tampung', title = "Line Plot Tahun Pendirian dan Daya Tampung")
# Out:
# <AxesSubplot:title={'center':'Line Plot Tahun Pendirian dan Daya Tampung'}, xlabel='tahun_pendirian'>

# %%
data.plot(kind="scatter", x = "tahun_pendirian", y = "daya_tampung", title = "Scatter Plot Tahun Pendirian dan Daya Tampung")
# Out:
# <AxesSubplot:title={'center':'Scatter Plot Tahun Pendirian dan Daya Tampung'}, xlabel='tahun_pendirian', ylabel='daya_tampung'>

# %%
data.plot(x = 'luas_bangunan', y = 'daya_tampung', title = "Line Plot Luas Bangunan dan Daya Tampung")
# Out:
# <AxesSubplot:title={'center':'Line Plot Luas Bangunan dan Daya Tampung'}, xlabel='luas_bangunan'>

# %%
data.plot(kind="scatter", x = "luas_bangunan", y = "daya_tampung", title = "Scatter Plot Luas Bangunan dan Daya Tampung")
# Out:
# <AxesSubplot:title={'center':'Scatter Plot Luas Bangunan dan Daya Tampung'}, xlabel='luas_bangunan', ylabel='daya_tampung'>

# %%
data.plot(x = 'luas_tanah', y = 'luas_bangunan', title = "Line Plot Luas Tanah dan Luas Bangunan")
# Out:
# <AxesSubplot:title={'center':'Line Plot Luas Tanah dan Luas Bangunan'}, xlabel='luas_tanah'>

# %%
data.plot(kind="scatter", x = "luas_tanah", y = "luas_bangunan", title = "Scatter Plot Luas Tanah dan Luas Bangunan")
# Out:
# <AxesSubplot:title={'center':'Scatter Plot Luas Tanah dan Luas Bangunan'}, xlabel='luas_tanah', ylabel='luas_bangunan'>

# %%
print("Korelasi Data")
print(data.corr())
print()
print("Visualisasi Korelasi Data")
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# Korelasi Data
#                  tahun_pendirian  daya_tampung  luas_bangunan  luas_tanah
# tahun_pendirian         1.000000      0.028134       0.015159    0.073665
# daya_tampung            0.028134      1.000000       0.453860    0.525275
# luas_bangunan           0.015159      0.453860       1.000000    0.514527
# luas_tanah              0.073665      0.525275       0.514527    1.000000
#
# Visualisasi Korelasi Data
# <style type="text/css">
# #T_4fb4f_row0_col0, #T_4fb4f_row1_col1, #T_4fb4f_row2_col2, #T_4fb4f_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4fb4f_row0_col1, #T_4fb4f_row0_col2, #T_4fb4f_row0_col3, #T_4fb4f_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4fb4f_row1_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4fb4f_row1_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_4fb4f_row1_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_4fb4f_row2_col1 {
# ...

# %% [markdown]
# Berdasarkan data korelasi data di atas, kita dapat melihat bahwa:
#
# Tahun Pendirian dengan daya tampung, luas bangunan, dan luas tanah:
# Nilai korelasi antara tahun pendirian dengan daya tampung, luas bangunan, luas tanah hampir mendekati nol. Artinya tidak terdapat hubungan antara tahun pedirian dengan daya tampung, luas bangunan, ataupun luas tanah.
#
# Daya Tampung dengan Luas Bangunan dan Luas Tanah:
# Nilai korelasi antara daya tampung dengan luas bangunan dan luas tanah hampir mendekati 1. Artinya nilai daya tampung dengan luas bangunan dan luas tanah berbanding lurus.

# %%
print("Data Kotor dalam Persen:")
persen = data.isnull().mean() * 100
print(round(persen,2))
# Out:
# Data Kotor dalam Persen:
# kab/kota              0.00
# kecamatan             0.00
# kelurahan             1.19
# tempat_ibadah         0.00
# alamat                0.00
# nama_pengurus        10.03
# status_tanah         31.27
# tahun_pendirian      34.80
# bentuk_bangunan      30.73
# sumber_biaya         79.46
# peruntukkan_lahan    86.02
# kepemilikkan         88.35
# pemberi_Wakaf        95.28
# daya_tampung         78.92
# luas_bangunan        28.51
# luas_tanah           25.47
# kegiatan_lain        92.14
# dtype: float64

# %% [markdown]
# Berdasarkan informasi persen data yang kosong di atas, data untuk atribut 'kab/kota', 'kecamatan', 'tempat_ibadah', dan 'alamat' tidak terdapat data yang kosong, namun untuk atribut lainnya terdapat data yang kosong dengan persentase pada informasi di atas.
